# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x,y)
plt.plot(x,z)
plt.xlabel("x")
plt.ylabel("y and z")
plt.legend(["y","z"])
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, [ax1, ax2] = plt.subplots(1,2)
ax1.plot(x,y)
ax1.set_title("Multiple of 2")
ax1.set_xlabel("x")
ax1.set_ylabel("y")

ax2.plot(x,z)
ax2.set_title("Square of x")
ax2.set_xlabel("x")
ax2.set_ylabel("z")

plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
print("Plot in its default size :")

plt.plot(x,y)
plt.plot(x,z)
plt.xlabel("x")
plt.ylabel("y and z")
plt.legend(["y","z"])
plt.show()

f = plt.figure()
f.set_figwidth(2)
f.set_figheight(5)

print("Plotafter re-sizing:")
plt.plot(x,y)
plt.plot(x,z)
plt.show()
# Out:
# Plot in its default size :
# Plotafter re-sizing:

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
x1 = np.linspace(-1, 2, 100)
y1 = x**2
y2 = np.exp(x)

fig, [ax1, ax2] = plt.subplots(1,2)
ax1.plot(x1,y1)
plt.xscale("linear")

ax2.plot(x1,y2)
plt.yscale("log")

plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# loading the data
fitbit = pd.read_csv("Fitbit2.csv")

# runs the first 3 rows
fitbit.head(3)
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# 0               1680  ...        0.403891    Friday           4.0
# 1               2248  ...        8.767545  Saturday           5.0
# 2               1719  ...        6.567891    Sunday           6.0
#
#    Work_or_Weekend  Hours Sleep Sleep efficiency  Yesterday_sleep  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
median_steps_by_month_df = fitbit.groupby(fitbit["Months_encoded"]).median()
median_steps_by_month_df['Months_encoded'] = median_steps_by_month_df.index
median_steps_by_month_df.head(3)

ax = sns.lineplot(x = 'Months_encoded', y = 'Steps', data = median_steps_by_month_df)
sns.set(rc={'figure.figsize':(12,4)})
plt.sca(ax)
plt.xticks()

# MEDIAN STEPS BY WORK_OR_WEEKEND
median_steps_by_work_or_weekend_df = fitbit.groupby(fitbit["Work_or_Weekend"]).median()
median_steps_by_work_or_weekend_df["Work_or_Weekend"] = median_steps_by_work_or_weekend_df.index

ax = sns.lineplot(x = 'Work_or_Weekend', y = 'Steps', data = median_steps_by_work_or_weekend_df)
sns.set(rc={'figure.figsize':(12,4)})
plt.sca(ax)
plt.xticks()

ax.secondary_xaxis('top')
ax.set_title('Median steps plot')

plt.show()

# %%
#### Write a loop to plot 3 scatter plots of the following features:

* Minutes Lightly Active vs Steps    
* Minutes Very Active vs Steps    
* Minutes Sedentary vs Steps
# Out:
#   File "<ipython-input-10-f7b8c78048be>", line 3
#     * Minutes Lightly Active vs Steps
#               ^
# SyntaxError: invalid syntax

# %%
# your code here
#plt.savefig('fitbit_steps_plot.pdf')

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv('titanic.csv')
titanic.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes(include='number')
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes(include='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
plt.style.use('classic')
plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
plt.hist(x = 'Age', data = titanic)

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
fig, axs = plt.subplots(1, 3)

axs[0].hist(x = 'Age', data = titanic, bins = 10)
axs[1].hist(x = 'Age', data = titanic, bins = 20)
axs[2].hist(x = 'Age', data = titanic, bins = 50)

plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.histplot(titanic['Age'])

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
titanic_gender_df = titanic.groupby(titanic['Gender']).count()
titanic_gender_df['Gender'] = titanic_gender_df.index
plt.bar(titanic_gender_df['Gender'], titanic_gender_df['PassengerId'])
# Out:
# <BarContainer object of 2 artists>

# %%
# Method 2 - seaborn
# your code here
sns.catplot(x="Gender", kind="count", data=titanic)

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
sns.catplot(x="Pclass", kind="count", data=titanic)

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
titanic.boxplot(column='Age')
plt.text(x=0.74, y=37.0, s="3rd Quartile")
plt.text(x=0.8, y=28.5, s="Median")
plt.text(x=0.75, y=15.5, s="1st Quartile")
plt.text(x=0.9, y=0.17, s="Min")
plt.text(x=0.9, y=80.0, s="Max")
plt.text(x=0.7, y=25.0, s="IQR", rotation=90, size=25)
# Out:
# Text(0.7, 25.0, 'IQR')

# %%
"""
your comments here
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
titanic.boxplot(column='Age')
plt.text(x=1.0, y=37.0, s="3rd Quartile")
plt.text(x=1.0, y=28.5, s="Median")
plt.text(x=1.0, y=15.5, s="1st Quartile")
plt.text(x=1.0, y=0.17, s="Min")
plt.text(x=1.0, y=80.0, s="Max")
plt.hist(x = 'Age', data = titanic, orientation='horizontal')
# Out:
# (array([ 72.,  78., 326., 347., 220., 136.,  75.,  42.,  10.,   3.]),
#  array([ 0.17 ,  8.153, 16.136, 24.119, 32.102, 40.085, 48.068, 56.051,
#         64.034, 72.017, 80.   ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# Scatter plot of Fare and Age
plt.scatter(titanic['Fare'], titanic['Age'])
plt.xlabel('Fare')
plt.ylabel('Age')
plt.title('Scatter plot of Fare and Age')
# Out:
# Text(0.5, 1.0, 'Scatter plot of Fare and Age')

# %%
# Method 2 - seaborn
sns.scatterplot(x='Fare', y='Age', data=titanic)
plt.xlabel('Fare')
plt.ylabel('Age')
plt.title('Scatter plot of Fare and Age')
# Out:
# Text(0.5, 1.0, 'Scatter plot of Fare and Age')

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
sns.heatmap(titanic.corr())

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
titanic_pclass_df = titanic.groupby(titanic['Pclass'])
titanic_pclass_df.boxplot(column='Age')
# Out:
# 1         AxesSubplot(0.1,0.559091;0.363636x0.340909)
# 2    AxesSubplot(0.536364,0.559091;0.363636x0.340909)
# 3             AxesSubplot(0.1,0.15;0.363636x0.340909)
# dtype: object

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
g = sns.FacetGrid(data=titanic, row='Gender')
g.map_dataframe(sns.histplot, x='Age')
